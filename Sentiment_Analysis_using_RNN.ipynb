# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek9686/Tensorflow/blob/master/Sentiment_Analysis_using_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==2.0.0
# Out:
# ...
#      |████████████████████████████████| 380.8MB 45kB/s
# ...
#      |████████████████████████████████| 450kB 35.1MB/s
# ...
#      |████████████████████████████████| 3.8MB 37.6MB/s
# ...
#      |████████████████████████████████| 81kB 10.6MB/s
# ...
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.0.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorboard 2.0.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.7.1 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
# ...

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
from tensorflow.keras.datasets import imdb

# %%
no_of_words=20000

# %%
max_len=100

# %%
(X_train,y_train),(X_test,y_test)=imdb.load_data(num_words=no_of_words)
# Out:
# ...
# 17465344/17464789 [==============================] - 1s 0us/step

# %%
X_train=tf.keras.preprocessing.sequence.pad_sequences(X_train,maxlen=max_len)

# %%
X_test=tf.keras.preprocessing.sequence.pad_sequences(X_test,maxlen=max_len)

# %%
model=tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Embedding(input_dim=no_of_words,output_dim=128,input_shape=(X_train.shape[1],)))

# %%
model.add(tf.keras.layers.LSTM(units=128,activation='tanh'))

# %%
model.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 100, 128)          2560000
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# ...
# Total params: 2,691,713
# Trainable params: 2,691,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=3,batch_size=128)
# Out:
# Train on 25000 samples
# Epoch 1/3
# 25000/25000 [==============================] - 16s 652us/sample - loss: 0.4676 - accuracy: 0.7900
# Epoch 2/3
# 25000/25000 [==============================] - 11s 453us/sample - loss: 0.2853 - accuracy: 0.8849
# Epoch 3/3
# 25000/25000 [==============================] - 11s 459us/sample - loss: 0.2346 - accuracy: 0.9101

# %%
test_loss,test_accuracy=model.evaluate(X_test,y_test)
# Out:
# 25000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print("test accuracy{}".format(test_accuracy))
# Out:
# test accuracy0.850600004196167
